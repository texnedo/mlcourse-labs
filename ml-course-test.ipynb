# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([1,2,3,4,5])

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = np.array([1,2,3,4,5]).transpose()

# %%
b
# Out:
# array([1, 2, 3, 4, 5])

# %%
dt = pd.read_csv(filepath_or_buffer='./mlcourse.ai/data/beauty.csv', sep=';')

# %%
dt.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
dt.describe()
# Out:
#               wage        exper        union     goodhlth        black  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      6.306690    18.206349     0.272222     0.933333     0.073810
# std       4.660639    11.963485     0.445280     0.249543     0.261564
# min       1.020000     0.000000     0.000000     0.000000     0.000000
# 25%       3.707500     8.000000     0.000000     1.000000     0.000000
# 50%       5.300000    15.000000     0.000000     1.000000     0.000000
# 75%       7.695000    27.000000     1.000000     1.000000     0.000000
# max      77.720000    48.000000     1.000000     1.000000     1.000000
#
#             female      married      service         educ        looks
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      0.346032     0.691270     0.273810    12.563492     3.185714
# std       0.475892     0.462153     0.446089     2.624489     0.684877
# ...

# %%
dt.tail()
# Out:
#       wage  exper  union  goodhlth  black  female  married  service  educ  \
# 1255  1.61     25      0         1      1       1        0        1    12
# 1256  1.68      4      0         1      0       1        1        1    12
# 1257  3.29     35      0         1      1       1        0        1    12
# 1258  2.31     15      0         1      1       1        1        1    10
# 1259  1.92     24      0         0      0       1        0        1    16
#
#       looks
# 1255      3
# 1256      2
# 1257      3
# 1258      3
# 1259      3

# %%
dt['wage']
# Out:
# 0        5.73
# 1        4.28
# 2        7.96
# 3       11.57
# 4       11.42
#         ...
# 1255     1.61
# 1256     1.68
# 1257     3.29
# 1258     2.31
# 1259     1.92
# Name: wage, Length: 1260, dtype: float64

# %%
dt['wage'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
dt.hist()
# Out:
# array([[<AxesSubplot:title={'center':'wage'}>,
#         <AxesSubplot:title={'center':'exper'}>,
#         <AxesSubplot:title={'center':'union'}>],
#        [<AxesSubplot:title={'center':'goodhlth'}>,
#         <AxesSubplot:title={'center':'black'}>,
#         <AxesSubplot:title={'center':'female'}>],
#        [<AxesSubplot:title={'center':'married'}>,
#         <AxesSubplot:title={'center':'service'}>,
#         <AxesSubplot:title={'center':'educ'}>],
#        [<AxesSubplot:title={'center':'looks'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
dt['female'].value_counts()
# Out:
# 0    824
# 1    436
# Name: female, dtype: int64

# %%
dt['looks'].unique()
# Out:
# array([4, 3, 2, 5, 1])

# %%
dt['looks'].nunique()
# Out:
# 5

# %%
some_dt = pd.DataFrame({'some':[1,2,3], 'test':[3,4,5]})

# %%
some_dt.describe()
# Out:
#        some  test
# count   3.0   3.0
# mean    2.0   4.0
# std     1.0   1.0
# min     1.0   3.0
# 25%     1.5   3.5
# 50%     2.0   4.0
# 75%     2.5   4.5
# max     3.0   5.0

# %%
dt.iloc[1,1]
# Out:
# 28

# %%
dt[dt['wage'] > dt['wage'].mean()]
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 2      7.96     35      0         1      0       1        0        0    10
# 3     11.57     38      0         1      0       0        1        1    16
# 4     11.42     27      0         1      0       0        1        0    16
# 6      8.76     12      0         1      0       0        1        0    16
# 7      7.69      5      1         1      0       0        0        0    16
# ...     ...    ...    ...       ...    ...     ...      ...      ...   ...
# 1245   6.73     34      0         1      0       0        1        0    10
# 1248  10.58     19      0         1      0       0        0        0    16
# 1249   8.65     10      1         1      0       0        1        0    13
# 1251   6.81      7      1         1      0       0        0        0    12
# 1252   9.62     21      1         1      0       0        1        0    16
#
#       looks
# 2         4
# 3         3
# 4         3
# 6         3
# ...

# %%
dt['female'].apply(lambda gender: 'male' if gender == 1 else 'female').head()
# Out:
# 0      male
# 1      male
# 2      male
# 3    female
# 4    female
# Name: female, dtype: object

# %%
dt.head().to_json()
# Out:
# '{"wage":{"0":5.73,"1":4.28,"2":7.96,"3":11.57,"4":11.42},"exper":{"0":30,"1":28,"2":35,"3":38,"4":27},"union":{"0":0,"1":0,"2":0,"3":0,"4":0},"goodhlth":{"0":1,"1":1,"2":1,"3":1,"4":1},"black":{"0":0,"1":0,"2":0,"3":0,"4":0},"female":{"0":1,"1":1,"2":1,"3":0,"4":0},"married":{"0":1,"1":1,"2":0,"3":1,"4":1},"service":{"0":1,"1":0,"2":0,"3":1,"4":0},"educ":{"0":14,"1":12,"2":10,"3":16,"4":16},"looks":{"0":4,"1":3,"2":4,"3":3,"4":3}}'

# %%
dt.groupby('female').agg({'wage':'mean'})
# Out:
#             wage
# female
# 0       7.368823
# 1       4.299358

# %%
dt.groupby('female').agg({'goodhlth':'mean'})
# Out:
#         goodhlth
# female
# 0       0.940534
# 1       0.919725

# %%
dt.groupby('female').agg({'goodhlth':'count'})
# Out:
#         goodhlth
# female
# 0            824
# 1            436

# %%
dt.loc[(dt['female'] == 1) & (dt['goodhlth'] == 1)]
# Out:
#       wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0     5.73     30      0         1      0       1        1        1    14
# 1     4.28     28      0         1      0       1        1        0    12
# 2     7.96     35      0         1      0       1        0        0    10
# 8     5.00      5      0         1      0       1        0        0    16
# 9     3.89     12      0         1      0       1        0        0    12
# ...    ...    ...    ...       ...    ...     ...      ...      ...   ...
# 1254  1.79     20      0         1      0       1        1        1     8
# 1255  1.61     25      0         1      1       1        0        1    12
# 1256  1.68      4      0         1      0       1        1        1    12
# 1257  3.29     35      0         1      1       1        0        1    12
# 1258  2.31     15      0         1      1       1        1        1    10
#
#       looks
# 0         4
# 1         3
# 2         4
# 8         3
# ...

# %%
dt.filter(["wage", "female"])
# Out:
#        wage  female
# 0      5.73       1
# 1      4.28       1
# 2      7.96       1
# 3     11.57       0
# 4     11.42       0
# ...     ...     ...
# 1255   1.61       1
# 1256   1.68       1
# 1257   3.29       1
# 1258   2.31       1
# 1259   1.92       1
#
# [1260 rows x 2 columns]

# %%
pd.crosstab(dt['female'], dt['married'])
# Out:
# married    0    1
# female
# 0        166  658
# 1        223  213

# %%
import seaborn as sns

# %%
dt['educ'].value_counts()
# Out:
# 12    468
# 13    246
# 10    156
# 17    132
# 16    121
# 14     51
# 8      44
# 5      42
# Name: educ, dtype: int64

# %%
dt['wage'].value_counts()
# Out:
# 3.75     36
# 7.69     32
# 4.81     28
# 1.98     24
# 7.96     21
#          ..
# 3.13      1
# 9.10      1
# 11.81     1
# 6.99      1
# 2.37      1
# Name: wage, Length: 520, dtype: int64

# %%
sns.boxplot(x='wage', data=dt[dt['wage'] < 30])
# Out:
# <AxesSubplot:xlabel='wage'>

# %%
sns.boxplot(x='educ', y='wage',data=dt[dt['wage'] < 30])
# Out:
# <AxesSubplot:xlabel='educ', ylabel='wage'>

# %%
sns.boxplot(x='goodhlth', y='wage',data=dt[dt['wage'] < 30])
# Out:
# <AxesSubplot:xlabel='goodhlth', ylabel='wage'>

# %%
df = pd.read_csv('./mlcourse.ai/data/telecom_churn.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.groupby(['Area code'])['Total day calls'].agg([np.mean, np.max, np.min, np.std])
# Out:
#                  mean  amax  amin        std
# Area code
# 408        100.496420   158    30  19.694243
# 415        100.576435   165     0  20.251354
# 510        100.097619   158     0  20.098565

# %%
columns_to_show = ['Total day minutes', 
                   'Total eve minutes', 
                   'Total night minutes']

df.groupby(['Churn'])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
#       Total day minutes                        Total eve minutes             \
#                    mean        std amin   amax              mean        std
# Churn
# False        175.175754  50.181655  0.0  315.6        199.043298  50.292175
# True         206.914079  68.997792  0.0  350.8        212.410145  51.728910
#
#                    Total night minutes
#        amin   amax                mean        std  amin   amax
# Churn
# False   0.0  361.8          200.133193  51.105032  23.2  395.0
# True   70.9  363.7          205.231677  47.132825  47.4  354.9

# %%
pd.crosstab(df['Churn'], df['International plan'])
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %%
sns.countplot(x='International plan', hue='Churn', data=df);

# %%
sns.countplot(x='Customer service calls', hue='Churn', data=df);

# %%
df['Many_service_calls'] = (df['Customer service calls'] > 3).astype('int')

pd.crosstab(df['Many_service_calls'], df['Churn'], margins=True)
# Out:
# Churn               False  True   All
# Many_service_calls
# 0                    2721   345  3066
# 1                     129   138   267
# All                  2850   483  3333

# %%
data = pd.read_csv('./mlcourse.ai/data/titanic_train.csv',
                  index_col='PassengerId')

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Survived'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'SibSp'}>],
#        [<AxesSubplot:title={'center':'Parch'}>,
#         <AxesSubplot:title={'center':'Fare'}>]], dtype=object)

# %%
data.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
data['Survived']
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
plt.scatter(data['Age'], data['Survived'])

# %%
from sklearn.manifold import TSNE

# %%
data.shape
# Out:
# (891, 11)

# %%
df.shape
# Out:
# (3333, 21)

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
tsne = TSNE(random_state=17)

# %%
x_repr = tsne.fit_transform(dt)

# %%
print(x_repr)
# Out:
# [[-30.172302 -18.13932 ]
#  [-19.210224 -25.43801 ]
#  [-41.800957 -18.507654]
#  ...
#  [-43.138325 -22.998608]
#  [ 22.87744  -17.1274  ]
#  [ -7.078904 -25.773888]]

# %%
dt.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
plt.scatter(x_repr[:,0], x_repr[:,1])

# %%
#x_repr1 = tsne.fit_transform(data)
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data1 = data[{"Survived", "Pclass", "Age", "Fare"}]
data1.head()
# Out:
#              Survived     Fare   Age  Pclass
# PassengerId
# 1                   0   7.2500  22.0       3
# 2                   1  71.2833  38.0       1
# 3                   1   7.9250  26.0       3
# 4                   1  53.1000  35.0       1
# 5                   0   8.0500  35.0       3

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(data['Sex'].astype(str))
data['Sex'] = le.transform(data['Sex'].astype(str))

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
le1 = LabelEncoder()
le1.fit(data['Cabin'].astype(str))
data['Cabin'] = le1.transform(data['Cabin'].astype(str))

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
#
#              SibSp  Parch            Ticket     Fare  Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500    147        S
# 2                1      0          PC 17599  71.2833     81        C
# 3                0      0  STON/O2. 3101282   7.9250    147        S
# ...

# %%
le2 = LabelEncoder()
le2.fit(data['Embarked'].astype(str))
data['Embarked'] = le2.transform(data['Embarked'].astype(str))

# %%
data_titanic = data[{"Survived", "Pclass", "Sex", "Fare", "Cabin", "Embarked"}]
data_titanic.corr()
# Out:
#             Pclass  Survived      Fare       Sex  Embarked     Cabin
# Pclass    1.000000 -0.338481 -0.549500  0.131900  0.157112  0.684121
# Survived -0.338481  1.000000  0.257307 -0.543351 -0.163517 -0.254888
# Fare     -0.549500  0.257307  1.000000 -0.182333 -0.221226 -0.503355
# Sex       0.131900 -0.543351 -0.182333  1.000000  0.104057  0.096681
# Embarked  0.157112 -0.163517 -0.221226  0.104057  1.000000  0.193205
# Cabin     0.684121 -0.254888 -0.503355  0.096681  0.193205  1.000000

# %%
data_short = data[{"Survived", "Fare", "Cabin", "Embarked"}]
data_short.corr()
# Out:
#           Survived      Fare  Embarked     Cabin
# Survived  1.000000  0.257307 -0.163517 -0.254888
# Fare      0.257307  1.000000 -0.221226 -0.503355
# Embarked -0.163517 -0.221226  1.000000  0.193205
# Cabin    -0.254888 -0.503355  0.193205  1.000000

# %%
x_repr_titanic = tsne.fit_transform(data_short)

# %%
plt.scatter(x_repr_titanic[:,0], x_repr_titanic[:,1])
